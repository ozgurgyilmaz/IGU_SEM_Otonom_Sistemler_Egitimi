# %% [markdown]
# IGU SEM 2. OTONOM SISTEMLERI EGITIMI
# Bu kod blogu üzerinde google drive ile google colab platformalarinin eslesmesi saglanmaktadir. Eslesme esnasinda drive alaninizda  kod icersinde olan "IGUSEM_OTONOM" dosyasi olmak zorundadir.
#
# Özgür Gözüyilmaz
# Ocak 2026

# %%
import os
os.chdir('/content/drive/My Drive/IGUSEM_OTONOM')
# !pwd # ilk kod blogunun cıktısını bize veren bir kod blogudur.
# Out:
# /content/drive/My Drive/IGUSEM_OTONOM

# %%
import os
os.chdir('/content/drive/My Drive/IGUSEM_OTONOM')
# !pwd # ilk kod blogunun cıktısını bize veren bir kod blogudur.
# Out:
# /content/drive/My Drive/IGUSEM_OTONOM

# %%
print('Merhaba zgur')
# Out:
# Merhaba zgur

# %%
import sys #import python programlama dilinde kütüphane eklemeye yarayan bir kod blogudur.
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/IGUSEM_OTONOM')
# !pwd # ilk kod blogunun cıktısını bize veren bir kod blogudur.
# Out:
# /content/drive/My Drive/IGUSEM_OTONOM
